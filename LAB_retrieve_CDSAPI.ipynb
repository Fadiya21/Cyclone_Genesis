# %%
import os, time, shutil
# 1) Disable HDF5 file locking (safe on local disks)
os.environ["HDF5_USE_FILE_LOCKING"] = "FALSE"

# 2) (Optional) move outputs OFF OneDrive/Dropbox folders
# e.g., to something like: r"C:\Data\era5_clean"

# %%
import os

# %%
print(os.getcwd())
# Out:
# C:\Users\_s2218026

# %%
os.chdir('/Users/_s2218026/Documents/lab')

# %%
# !pip install numpy pandas xarray netCDF4 cdsapi scikit-learn matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: pandas in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: xarray in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (2025.4.0)
# Requirement already satisfied: netCDF4 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (1.7.3)
# Requirement already satisfied: cdsapi in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (0.7.7)
# Requirement already satisfied: scikit-learn in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (1.6.1)
# Requirement already satisfied: matplotlib in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: seaborn in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from xarray) (24.2)
# Requirement already satisfied: cftime in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from netCDF4) (1.6.5)
# Requirement already satisfied: certifi in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from netCDF4) (2025.10.5)
# Requirement already satisfied: ecmwf-datastores-client>=0.4.0 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from cdsapi) (0.4.0)
# Requirement already satisfied: requests>=2.5.0 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from cdsapi) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from cdsapi) (4.67.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pillow>=8 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: attrs in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from ecmwf-datastores-client>=0.4.0->cdsapi) (24.3.0)
# Requirement already satisfied: multiurl>=0.3.7 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from ecmwf-datastores-client>=0.4.0->cdsapi) (0.3.7)
# Requirement already satisfied: typing-extensions in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from ecmwf-datastores-client>=0.4.0->cdsapi) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from requests>=2.5.0->cdsapi) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from requests>=2.5.0->cdsapi) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from requests>=2.5.0->cdsapi) (2.3.0)
# Requirement already satisfied: colorama in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from tqdm->cdsapi) (0.4.6)

# %%
import cdsapi
import calendar
import time

# %%
c = cdsapi.Client()
print("cdsapi is working")
# Out:
# cdsapi is working

# %%
os.makedirs('./data', exist_ok=True)

# Create one client; add some robustness
c = cdsapi.Client()

# Tune these to shrink requests if needed
VAR_GROUPS = [
    ['u_component_of_wind','v_component_of_wind'],  # group 1
    ['temperature','relative_humidity'],             # group 2
    ['vorticity'],                                   # group 3
]
PLEV_GROUPS = [
    ['850'],   # do one level at a time to keep requests tiny
    ['600'],
    ['200'],
]
TIMES = ['00:00','12:00']  # reduce volume; use 4 times if you really need them

def days_in_month(y, m):
    return [f"{d:02d}" for d in range(1, calendar.monthrange(y, m)[1] + 1)]

def retrieve_small_month(y, m, vars_, plev_, outpath):
    # tiny request; retry a couple times with short backoff
    for attempt in range(3):
        try:
            print(f"→ {y}-{m:02d} vars={vars_} plev={plev_} -> {outpath}")
            c.retrieve(
                'reanalysis-era5-pressure-levels',
                {
                    'product_type': 'reanalysis',
                    'format': 'netcdf',
                    'variable': vars_,
                    'pressure_level': plev_,
                    'year': f"{y}",
                    'month': f"{m:02d}",
                    'day': days_in_month(y, m),
                    'time': TIMES,
                    'area': [30, 100, 0, 180],   # N, W, S, E
                    'grid': [0.25, 0.25],        # change to [0.5,0.5] if still too big
                },
                outpath
            )
            return
        except Exception as e:
            print(f"   attempt {attempt+1} failed: {e}")
            time.sleep(5*(attempt+1))
    raise RuntimeError(f"Failed after retries: {y}-{m:02d} {vars_} {plev_}")

def retrieve_range_small(start_year, end_year_inclusive):
    for y in range(start_year, end_year_inclusive+1):
        for m in range(1, 13):
            for vg in VAR_GROUPS:
                for pg in PLEV_GROUPS:
                    out = f'./data/era_{y}_{m:02d}_{"-".join(vg)}_{pg[0]}.nc'
                    if os.path.exists(out):
                        print(f"skip existing {out}")
                        continue
                    retrieve_small_month(y, m, vg, pg, out)

# %%
retrieve_range_small(1994, 2024)
# Out:
# skip existing ./data/era_1994_01_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_01_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_01_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_01_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_01_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_01_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_01_vorticity_850.nc
# skip existing ./data/era_1994_01_vorticity_600.nc
# skip existing ./data/era_1994_01_vorticity_200.nc
# skip existing ./data/era_1994_02_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_02_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_02_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_02_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_02_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_02_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_02_vorticity_850.nc
# skip existing ./data/era_1994_02_vorticity_600.nc
# skip existing ./data/era_1994_02_vorticity_200.nc
# skip existing ./data/era_1994_03_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_03_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_03_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_03_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_03_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_03_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_03_vorticity_850.nc
# skip existing ./data/era_1994_03_vorticity_600.nc
# skip existing ./data/era_1994_03_vorticity_200.nc
# skip existing ./data/era_1994_04_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_04_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_04_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_04_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_04_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_04_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_04_vorticity_850.nc
# skip existing ./data/era_1994_04_vorticity_600.nc
# skip existing ./data/era_1994_04_vorticity_200.nc
# skip existing ./data/era_1994_05_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_05_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_05_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_05_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_05_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_05_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_05_vorticity_850.nc
# skip existing ./data/era_1994_05_vorticity_600.nc
# skip existing ./data/era_1994_05_vorticity_200.nc
# skip existing ./data/era_1994_06_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_06_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_06_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_06_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_06_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_06_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_06_vorticity_850.nc
# skip existing ./data/era_1994_06_vorticity_600.nc
# skip existing ./data/era_1994_06_vorticity_200.nc
# skip existing ./data/era_1994_07_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_07_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_07_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_07_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_07_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_07_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_07_vorticity_850.nc
# skip existing ./data/era_1994_07_vorticity_600.nc
# skip existing ./data/era_1994_07_vorticity_200.nc
# skip existing ./data/era_1994_08_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_08_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_08_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_08_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_08_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_08_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_08_vorticity_850.nc
# skip existing ./data/era_1994_08_vorticity_600.nc
# skip existing ./data/era_1994_08_vorticity_200.nc
# skip existing ./data/era_1994_09_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_09_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_09_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_09_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_09_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_09_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_09_vorticity_850.nc
# skip existing ./data/era_1994_09_vorticity_600.nc
# skip existing ./data/era_1994_09_vorticity_200.nc
# skip existing ./data/era_1994_10_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_10_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_10_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_10_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_10_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_10_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_10_vorticity_850.nc
# skip existing ./data/era_1994_10_vorticity_600.nc
# skip existing ./data/era_1994_10_vorticity_200.nc
# skip existing ./data/era_1994_11_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_11_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_11_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_11_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_11_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_11_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_11_vorticity_850.nc
# skip existing ./data/era_1994_11_vorticity_600.nc
# skip existing ./data/era_1994_11_vorticity_200.nc
# skip existing ./data/era_1994_12_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1994_12_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1994_12_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1994_12_temperature-relative_humidity_850.nc
# skip existing ./data/era_1994_12_temperature-relative_humidity_600.nc
# skip existing ./data/era_1994_12_temperature-relative_humidity_200.nc
# skip existing ./data/era_1994_12_vorticity_850.nc
# skip existing ./data/era_1994_12_vorticity_600.nc
# skip existing ./data/era_1994_12_vorticity_200.nc
# skip existing ./data/era_1995_01_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_01_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_01_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_01_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_01_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_01_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_01_vorticity_850.nc
# skip existing ./data/era_1995_01_vorticity_600.nc
# skip existing ./data/era_1995_01_vorticity_200.nc
# skip existing ./data/era_1995_02_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_02_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_02_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_02_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_02_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_02_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_02_vorticity_850.nc
# skip existing ./data/era_1995_02_vorticity_600.nc
# skip existing ./data/era_1995_02_vorticity_200.nc
# skip existing ./data/era_1995_03_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_03_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_03_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_03_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_03_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_03_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_03_vorticity_850.nc
# skip existing ./data/era_1995_03_vorticity_600.nc
# skip existing ./data/era_1995_03_vorticity_200.nc
# skip existing ./data/era_1995_04_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_04_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_04_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_04_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_04_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_04_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_04_vorticity_850.nc
# skip existing ./data/era_1995_04_vorticity_600.nc
# skip existing ./data/era_1995_04_vorticity_200.nc
# skip existing ./data/era_1995_05_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_05_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_05_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_05_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_05_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_05_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_05_vorticity_850.nc
# skip existing ./data/era_1995_05_vorticity_600.nc
# skip existing ./data/era_1995_05_vorticity_200.nc
# skip existing ./data/era_1995_06_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_06_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_06_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_06_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_06_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_06_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_06_vorticity_850.nc
# skip existing ./data/era_1995_06_vorticity_600.nc
# skip existing ./data/era_1995_06_vorticity_200.nc
# skip existing ./data/era_1995_07_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_07_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_07_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_07_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_07_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_07_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_07_vorticity_850.nc
# skip existing ./data/era_1995_07_vorticity_600.nc
# skip existing ./data/era_1995_07_vorticity_200.nc
# skip existing ./data/era_1995_08_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_08_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_08_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_08_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_08_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_08_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_08_vorticity_850.nc
# skip existing ./data/era_1995_08_vorticity_600.nc
# skip existing ./data/era_1995_08_vorticity_200.nc
# skip existing ./data/era_1995_09_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_09_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_09_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_09_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_09_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_09_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_09_vorticity_850.nc
# skip existing ./data/era_1995_09_vorticity_600.nc
# skip existing ./data/era_1995_09_vorticity_200.nc
# skip existing ./data/era_1995_10_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_10_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_10_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_10_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_10_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_10_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_10_vorticity_850.nc
# skip existing ./data/era_1995_10_vorticity_600.nc
# skip existing ./data/era_1995_10_vorticity_200.nc
# skip existing ./data/era_1995_11_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_11_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_11_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_11_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_11_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_11_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_11_vorticity_850.nc
# skip existing ./data/era_1995_11_vorticity_600.nc
# skip existing ./data/era_1995_11_vorticity_200.nc
# skip existing ./data/era_1995_12_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1995_12_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1995_12_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1995_12_temperature-relative_humidity_850.nc
# skip existing ./data/era_1995_12_temperature-relative_humidity_600.nc
# skip existing ./data/era_1995_12_temperature-relative_humidity_200.nc
# skip existing ./data/era_1995_12_vorticity_850.nc
# skip existing ./data/era_1995_12_vorticity_600.nc
# skip existing ./data/era_1995_12_vorticity_200.nc
# skip existing ./data/era_1996_01_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_01_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_01_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_01_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_01_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_01_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_01_vorticity_850.nc
# skip existing ./data/era_1996_01_vorticity_600.nc
# skip existing ./data/era_1996_01_vorticity_200.nc
# skip existing ./data/era_1996_02_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_02_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_02_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_02_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_02_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_02_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_02_vorticity_850.nc
# skip existing ./data/era_1996_02_vorticity_600.nc
# skip existing ./data/era_1996_02_vorticity_200.nc
# skip existing ./data/era_1996_03_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_03_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_03_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_03_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_03_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_03_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_03_vorticity_850.nc
# skip existing ./data/era_1996_03_vorticity_600.nc
# skip existing ./data/era_1996_03_vorticity_200.nc
# skip existing ./data/era_1996_04_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_04_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_04_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_04_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_04_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_04_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_04_vorticity_850.nc
# skip existing ./data/era_1996_04_vorticity_600.nc
# skip existing ./data/era_1996_04_vorticity_200.nc
# skip existing ./data/era_1996_05_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_05_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_05_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_05_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_05_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_05_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_05_vorticity_850.nc
# skip existing ./data/era_1996_05_vorticity_600.nc
# skip existing ./data/era_1996_05_vorticity_200.nc
# skip existing ./data/era_1996_06_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_06_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_06_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_06_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_06_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_06_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_06_vorticity_850.nc
# skip existing ./data/era_1996_06_vorticity_600.nc
# skip existing ./data/era_1996_06_vorticity_200.nc
# skip existing ./data/era_1996_07_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_07_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_07_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_07_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_07_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_07_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_07_vorticity_850.nc
# skip existing ./data/era_1996_07_vorticity_600.nc
# skip existing ./data/era_1996_07_vorticity_200.nc
# skip existing ./data/era_1996_08_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_08_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_08_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_08_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_08_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_08_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_08_vorticity_850.nc
# skip existing ./data/era_1996_08_vorticity_600.nc
# skip existing ./data/era_1996_08_vorticity_200.nc
# skip existing ./data/era_1996_09_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_09_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_09_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_09_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_09_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_09_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_09_vorticity_850.nc
# skip existing ./data/era_1996_09_vorticity_600.nc
# skip existing ./data/era_1996_09_vorticity_200.nc
# skip existing ./data/era_1996_10_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_10_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_10_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_10_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_10_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_10_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_10_vorticity_850.nc
# skip existing ./data/era_1996_10_vorticity_600.nc
# skip existing ./data/era_1996_10_vorticity_200.nc
# skip existing ./data/era_1996_11_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_11_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_11_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_11_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_11_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_11_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_11_vorticity_850.nc
# skip existing ./data/era_1996_11_vorticity_600.nc
# skip existing ./data/era_1996_11_vorticity_200.nc
# skip existing ./data/era_1996_12_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1996_12_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1996_12_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1996_12_temperature-relative_humidity_850.nc
# skip existing ./data/era_1996_12_temperature-relative_humidity_600.nc
# skip existing ./data/era_1996_12_temperature-relative_humidity_200.nc
# skip existing ./data/era_1996_12_vorticity_850.nc
# skip existing ./data/era_1996_12_vorticity_600.nc
# skip existing ./data/era_1996_12_vorticity_200.nc
# skip existing ./data/era_1997_01_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_01_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_01_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_01_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_01_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_01_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_01_vorticity_850.nc
# skip existing ./data/era_1997_01_vorticity_600.nc
# skip existing ./data/era_1997_01_vorticity_200.nc
# skip existing ./data/era_1997_02_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_02_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_02_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_02_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_02_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_02_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_02_vorticity_850.nc
# skip existing ./data/era_1997_02_vorticity_600.nc
# skip existing ./data/era_1997_02_vorticity_200.nc
# skip existing ./data/era_1997_03_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_03_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_03_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_03_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_03_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_03_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_03_vorticity_850.nc
# skip existing ./data/era_1997_03_vorticity_600.nc
# skip existing ./data/era_1997_03_vorticity_200.nc
# skip existing ./data/era_1997_04_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_04_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_04_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_04_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_04_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_04_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_04_vorticity_850.nc
# skip existing ./data/era_1997_04_vorticity_600.nc
# skip existing ./data/era_1997_04_vorticity_200.nc
# skip existing ./data/era_1997_05_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_05_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_05_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_05_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_05_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_05_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_05_vorticity_850.nc
# skip existing ./data/era_1997_05_vorticity_600.nc
# skip existing ./data/era_1997_05_vorticity_200.nc
# skip existing ./data/era_1997_06_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_06_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_06_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_06_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_06_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_06_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_06_vorticity_850.nc
# skip existing ./data/era_1997_06_vorticity_600.nc
# skip existing ./data/era_1997_06_vorticity_200.nc
# skip existing ./data/era_1997_07_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_07_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_07_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_07_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_07_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_07_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_07_vorticity_850.nc
# skip existing ./data/era_1997_07_vorticity_600.nc
# skip existing ./data/era_1997_07_vorticity_200.nc
# skip existing ./data/era_1997_08_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_08_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_08_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_08_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_08_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_08_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_08_vorticity_850.nc
# skip existing ./data/era_1997_08_vorticity_600.nc
# skip existing ./data/era_1997_08_vorticity_200.nc
# skip existing ./data/era_1997_09_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_09_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_09_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_09_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_09_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_09_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_09_vorticity_850.nc
# skip existing ./data/era_1997_09_vorticity_600.nc
# skip existing ./data/era_1997_09_vorticity_200.nc
# skip existing ./data/era_1997_10_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_10_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_10_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_10_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_10_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_10_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_10_vorticity_850.nc
# skip existing ./data/era_1997_10_vorticity_600.nc
# skip existing ./data/era_1997_10_vorticity_200.nc
# skip existing ./data/era_1997_11_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_11_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_11_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_11_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_11_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_11_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_11_vorticity_850.nc
# skip existing ./data/era_1997_11_vorticity_600.nc
# skip existing ./data/era_1997_11_vorticity_200.nc
# skip existing ./data/era_1997_12_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1997_12_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1997_12_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1997_12_temperature-relative_humidity_850.nc
# skip existing ./data/era_1997_12_temperature-relative_humidity_600.nc
# skip existing ./data/era_1997_12_temperature-relative_humidity_200.nc
# skip existing ./data/era_1997_12_vorticity_850.nc
# skip existing ./data/era_1997_12_vorticity_600.nc
# skip existing ./data/era_1997_12_vorticity_200.nc
# skip existing ./data/era_1998_01_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_01_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_01_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_01_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_01_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_01_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_01_vorticity_850.nc
# skip existing ./data/era_1998_01_vorticity_600.nc
# skip existing ./data/era_1998_01_vorticity_200.nc
# skip existing ./data/era_1998_02_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_02_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_02_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_02_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_02_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_02_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_02_vorticity_850.nc
# skip existing ./data/era_1998_02_vorticity_600.nc
# skip existing ./data/era_1998_02_vorticity_200.nc
# skip existing ./data/era_1998_03_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_03_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_03_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_03_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_03_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_03_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_03_vorticity_850.nc
# skip existing ./data/era_1998_03_vorticity_600.nc
# skip existing ./data/era_1998_03_vorticity_200.nc
# skip existing ./data/era_1998_04_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_04_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_04_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_04_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_04_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_04_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_04_vorticity_850.nc
# skip existing ./data/era_1998_04_vorticity_600.nc
# skip existing ./data/era_1998_04_vorticity_200.nc
# skip existing ./data/era_1998_05_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_05_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_05_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_05_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_05_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_05_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_05_vorticity_850.nc
# skip existing ./data/era_1998_05_vorticity_600.nc
# skip existing ./data/era_1998_05_vorticity_200.nc
# skip existing ./data/era_1998_06_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_06_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_06_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_06_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_06_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_06_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_06_vorticity_850.nc
# skip existing ./data/era_1998_06_vorticity_600.nc
# skip existing ./data/era_1998_06_vorticity_200.nc
# skip existing ./data/era_1998_07_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_07_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_07_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_07_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_07_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_07_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_07_vorticity_850.nc
# skip existing ./data/era_1998_07_vorticity_600.nc
# skip existing ./data/era_1998_07_vorticity_200.nc
# skip existing ./data/era_1998_08_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_08_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_08_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_08_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_08_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_08_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_08_vorticity_850.nc
# skip existing ./data/era_1998_08_vorticity_600.nc
# skip existing ./data/era_1998_08_vorticity_200.nc
# skip existing ./data/era_1998_09_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_09_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_09_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_09_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_09_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_09_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_09_vorticity_850.nc
# skip existing ./data/era_1998_09_vorticity_600.nc
# skip existing ./data/era_1998_09_vorticity_200.nc
# skip existing ./data/era_1998_10_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_10_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_10_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_10_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_10_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_10_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_10_vorticity_850.nc
# skip existing ./data/era_1998_10_vorticity_600.nc
# skip existing ./data/era_1998_10_vorticity_200.nc
# skip existing ./data/era_1998_11_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_11_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_11_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_11_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_11_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_11_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_11_vorticity_850.nc
# skip existing ./data/era_1998_11_vorticity_600.nc
# skip existing ./data/era_1998_11_vorticity_200.nc
# skip existing ./data/era_1998_12_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1998_12_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1998_12_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1998_12_temperature-relative_humidity_850.nc
# skip existing ./data/era_1998_12_temperature-relative_humidity_600.nc
# skip existing ./data/era_1998_12_temperature-relative_humidity_200.nc
# skip existing ./data/era_1998_12_vorticity_850.nc
# skip existing ./data/era_1998_12_vorticity_600.nc
# skip existing ./data/era_1998_12_vorticity_200.nc
# skip existing ./data/era_1999_01_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_01_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_01_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_01_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_01_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_01_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_01_vorticity_850.nc
# skip existing ./data/era_1999_01_vorticity_600.nc
# skip existing ./data/era_1999_01_vorticity_200.nc
# skip existing ./data/era_1999_02_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_02_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_02_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_02_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_02_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_02_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_02_vorticity_850.nc
# skip existing ./data/era_1999_02_vorticity_600.nc
# skip existing ./data/era_1999_02_vorticity_200.nc
# skip existing ./data/era_1999_03_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_03_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_03_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_03_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_03_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_03_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_03_vorticity_850.nc
# skip existing ./data/era_1999_03_vorticity_600.nc
# skip existing ./data/era_1999_03_vorticity_200.nc
# skip existing ./data/era_1999_04_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_04_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_04_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_04_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_04_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_04_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_04_vorticity_850.nc
# skip existing ./data/era_1999_04_vorticity_600.nc
# skip existing ./data/era_1999_04_vorticity_200.nc
# skip existing ./data/era_1999_05_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_05_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_05_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_05_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_05_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_05_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_05_vorticity_850.nc
# skip existing ./data/era_1999_05_vorticity_600.nc
# skip existing ./data/era_1999_05_vorticity_200.nc
# skip existing ./data/era_1999_06_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_06_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_06_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_06_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_06_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_06_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_06_vorticity_850.nc
# skip existing ./data/era_1999_06_vorticity_600.nc
# skip existing ./data/era_1999_06_vorticity_200.nc
# skip existing ./data/era_1999_07_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_07_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_07_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_07_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_07_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_07_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_07_vorticity_850.nc
# skip existing ./data/era_1999_07_vorticity_600.nc
# skip existing ./data/era_1999_07_vorticity_200.nc
# skip existing ./data/era_1999_08_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_08_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_08_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_08_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_08_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_08_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_08_vorticity_850.nc
# skip existing ./data/era_1999_08_vorticity_600.nc
# skip existing ./data/era_1999_08_vorticity_200.nc
# skip existing ./data/era_1999_09_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_09_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_09_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_09_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_09_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_09_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_09_vorticity_850.nc
# skip existing ./data/era_1999_09_vorticity_600.nc
# skip existing ./data/era_1999_09_vorticity_200.nc
# skip existing ./data/era_1999_10_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_10_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_10_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_10_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_10_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_10_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_10_vorticity_850.nc
# skip existing ./data/era_1999_10_vorticity_600.nc
# skip existing ./data/era_1999_10_vorticity_200.nc
# skip existing ./data/era_1999_11_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_11_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_11_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_11_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_11_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_11_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_11_vorticity_850.nc
# skip existing ./data/era_1999_11_vorticity_600.nc
# skip existing ./data/era_1999_11_vorticity_200.nc
# skip existing ./data/era_1999_12_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_1999_12_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_1999_12_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_1999_12_temperature-relative_humidity_850.nc
# skip existing ./data/era_1999_12_temperature-relative_humidity_600.nc
# skip existing ./data/era_1999_12_temperature-relative_humidity_200.nc
# skip existing ./data/era_1999_12_vorticity_850.nc
# skip existing ./data/era_1999_12_vorticity_600.nc
# skip existing ./data/era_1999_12_vorticity_200.nc
# skip existing ./data/era_2000_01_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2000_01_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2000_01_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2000_01_temperature-relative_humidity_850.nc
# skip existing ./data/era_2000_01_temperature-relative_humidity_600.nc
# skip existing ./data/era_2000_01_temperature-relative_humidity_200.nc
# skip existing ./data/era_2000_01_vorticity_850.nc
# skip existing ./data/era_2000_01_vorticity_600.nc
# skip existing ./data/era_2000_01_vorticity_200.nc
# skip existing ./data/era_2000_02_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2000_02_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2000_02_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2000_02_temperature-relative_humidity_850.nc
# skip existing ./data/era_2000_02_temperature-relative_humidity_600.nc
# skip existing ./data/era_2000_02_temperature-relative_humidity_200.nc
# skip existing ./data/era_2000_02_vorticity_850.nc
# skip existing ./data/era_2000_02_vorticity_600.nc
# skip existing ./data/era_2000_02_vorticity_200.nc
# skip existing ./data/era_2000_03_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2000_03_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2000_03_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2000_03_temperature-relative_humidity_850.nc
# skip existing ./data/era_2000_03_temperature-relative_humidity_600.nc
# skip existing ./data/era_2000_03_temperature-relative_humidity_200.nc
# skip existing ./data/era_2000_03_vorticity_850.nc
# skip existing ./data/era_2000_03_vorticity_600.nc
# skip existing ./data/era_2000_03_vorticity_200.nc
# skip existing ./data/era_2000_04_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2000_04_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2000_04_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2000_04_temperature-relative_humidity_850.nc
# skip existing ./data/era_2000_04_temperature-relative_humidity_600.nc
# skip existing ./data/era_2000_04_temperature-relative_humidity_200.nc
# skip existing ./data/era_2000_04_vorticity_850.nc
# skip existing ./data/era_2000_04_vorticity_600.nc
# skip existing ./data/era_2000_04_vorticity_200.nc
# skip existing ./data/era_2000_05_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2000_05_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2000_05_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2000_05_temperature-relative_humidity_850.nc
# skip existing ./data/era_2000_05_temperature-relative_humidity_600.nc
# skip existing ./data/era_2000_05_temperature-relative_humidity_200.nc
# skip existing ./data/era_2000_05_vorticity_850.nc
# skip existing ./data/era_2000_05_vorticity_600.nc
# skip existing ./data/era_2000_05_vorticity_200.nc
# skip existing ./data/era_2000_06_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2000_06_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2000_06_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2000_06_temperature-relative_humidity_850.nc
# skip existing ./data/era_2000_06_temperature-relative_humidity_600.nc
# skip existing ./data/era_2000_06_temperature-relative_humidity_200.nc
# skip existing ./data/era_2000_06_vorticity_850.nc
# skip existing ./data/era_2000_06_vorticity_600.nc
# skip existing ./data/era_2000_06_vorticity_200.nc
# skip existing ./data/era_2000_07_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2000_07_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2000_07_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2000_07_temperature-relative_humidity_850.nc
# skip existing ./data/era_2000_07_temperature-relative_humidity_600.nc
# skip existing ./data/era_2000_07_temperature-relative_humidity_200.nc
# skip existing ./data/era_2000_07_vorticity_850.nc
# skip existing ./data/era_2000_07_vorticity_600.nc
# skip existing ./data/era_2000_07_vorticity_200.nc
# skip existing ./data/era_2000_08_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2000_08_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2000_08_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2000_08_temperature-relative_humidity_850.nc
# skip existing ./data/era_2000_08_temperature-relative_humidity_600.nc
# skip existing ./data/era_2000_08_temperature-relative_humidity_200.nc
# skip existing ./data/era_2000_08_vorticity_850.nc
# skip existing ./data/era_2000_08_vorticity_600.nc
# skip existing ./data/era_2000_08_vorticity_200.nc
# ...
# skip existing ./data/era_2022_10_temperature-relative_humidity_850.nc
# skip existing ./data/era_2022_10_temperature-relative_humidity_600.nc
# skip existing ./data/era_2022_10_temperature-relative_humidity_200.nc
# skip existing ./data/era_2022_10_vorticity_850.nc
# skip existing ./data/era_2022_10_vorticity_600.nc
# skip existing ./data/era_2022_10_vorticity_200.nc
# skip existing ./data/era_2022_11_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2022_11_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2022_11_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2022_11_temperature-relative_humidity_850.nc
# skip existing ./data/era_2022_11_temperature-relative_humidity_600.nc
# skip existing ./data/era_2022_11_temperature-relative_humidity_200.nc
# skip existing ./data/era_2022_11_vorticity_850.nc
# skip existing ./data/era_2022_11_vorticity_600.nc
# skip existing ./data/era_2022_11_vorticity_200.nc
# skip existing ./data/era_2022_12_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2022_12_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2022_12_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2022_12_temperature-relative_humidity_850.nc
# skip existing ./data/era_2022_12_temperature-relative_humidity_600.nc
# skip existing ./data/era_2022_12_temperature-relative_humidity_200.nc
# skip existing ./data/era_2022_12_vorticity_850.nc
# skip existing ./data/era_2022_12_vorticity_600.nc
# skip existing ./data/era_2022_12_vorticity_200.nc
# skip existing ./data/era_2023_01_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_01_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_01_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_01_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_01_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_01_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_01_vorticity_850.nc
# skip existing ./data/era_2023_01_vorticity_600.nc
# skip existing ./data/era_2023_01_vorticity_200.nc
# skip existing ./data/era_2023_02_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_02_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_02_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_02_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_02_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_02_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_02_vorticity_850.nc
# skip existing ./data/era_2023_02_vorticity_600.nc
# skip existing ./data/era_2023_02_vorticity_200.nc
# skip existing ./data/era_2023_03_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_03_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_03_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_03_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_03_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_03_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_03_vorticity_850.nc
# skip existing ./data/era_2023_03_vorticity_600.nc
# skip existing ./data/era_2023_03_vorticity_200.nc
# skip existing ./data/era_2023_04_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_04_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_04_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_04_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_04_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_04_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_04_vorticity_850.nc
# skip existing ./data/era_2023_04_vorticity_600.nc
# skip existing ./data/era_2023_04_vorticity_200.nc
# skip existing ./data/era_2023_05_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_05_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_05_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_05_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_05_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_05_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_05_vorticity_850.nc
# skip existing ./data/era_2023_05_vorticity_600.nc
# skip existing ./data/era_2023_05_vorticity_200.nc
# skip existing ./data/era_2023_06_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_06_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_06_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_06_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_06_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_06_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_06_vorticity_850.nc
# skip existing ./data/era_2023_06_vorticity_600.nc
# skip existing ./data/era_2023_06_vorticity_200.nc
# skip existing ./data/era_2023_07_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_07_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_07_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_07_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_07_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_07_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_07_vorticity_850.nc
# skip existing ./data/era_2023_07_vorticity_600.nc
# skip existing ./data/era_2023_07_vorticity_200.nc
# skip existing ./data/era_2023_08_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_08_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_08_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_08_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_08_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_08_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_08_vorticity_850.nc
# skip existing ./data/era_2023_08_vorticity_600.nc
# skip existing ./data/era_2023_08_vorticity_200.nc
# skip existing ./data/era_2023_09_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_09_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_09_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_09_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_09_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_09_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_09_vorticity_850.nc
# skip existing ./data/era_2023_09_vorticity_600.nc
# skip existing ./data/era_2023_09_vorticity_200.nc
# skip existing ./data/era_2023_10_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_10_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_10_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_10_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_10_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_10_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_10_vorticity_850.nc
# skip existing ./data/era_2023_10_vorticity_600.nc
# skip existing ./data/era_2023_10_vorticity_200.nc
# skip existing ./data/era_2023_11_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_11_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_11_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_11_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_11_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_11_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_11_vorticity_850.nc
# skip existing ./data/era_2023_11_vorticity_600.nc
# skip existing ./data/era_2023_11_vorticity_200.nc
# skip existing ./data/era_2023_12_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2023_12_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2023_12_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2023_12_temperature-relative_humidity_850.nc
# skip existing ./data/era_2023_12_temperature-relative_humidity_600.nc
# skip existing ./data/era_2023_12_temperature-relative_humidity_200.nc
# skip existing ./data/era_2023_12_vorticity_850.nc
# skip existing ./data/era_2023_12_vorticity_600.nc
# skip existing ./data/era_2023_12_vorticity_200.nc
# skip existing ./data/era_2024_01_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_01_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_01_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_01_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_01_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_01_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_01_vorticity_850.nc
# skip existing ./data/era_2024_01_vorticity_600.nc
# skip existing ./data/era_2024_01_vorticity_200.nc
# skip existing ./data/era_2024_02_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_02_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_02_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_02_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_02_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_02_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_02_vorticity_850.nc
# skip existing ./data/era_2024_02_vorticity_600.nc
# skip existing ./data/era_2024_02_vorticity_200.nc
# skip existing ./data/era_2024_03_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_03_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_03_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_03_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_03_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_03_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_03_vorticity_850.nc
# skip existing ./data/era_2024_03_vorticity_600.nc
# skip existing ./data/era_2024_03_vorticity_200.nc
# skip existing ./data/era_2024_04_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_04_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_04_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_04_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_04_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_04_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_04_vorticity_850.nc
# skip existing ./data/era_2024_04_vorticity_600.nc
# skip existing ./data/era_2024_04_vorticity_200.nc
# skip existing ./data/era_2024_05_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_05_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_05_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_05_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_05_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_05_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_05_vorticity_850.nc
# skip existing ./data/era_2024_05_vorticity_600.nc
# skip existing ./data/era_2024_05_vorticity_200.nc
# skip existing ./data/era_2024_06_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_06_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_06_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_06_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_06_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_06_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_06_vorticity_850.nc
# skip existing ./data/era_2024_06_vorticity_600.nc
# skip existing ./data/era_2024_06_vorticity_200.nc
# skip existing ./data/era_2024_07_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_07_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_07_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_07_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_07_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_07_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_07_vorticity_850.nc
# skip existing ./data/era_2024_07_vorticity_600.nc
# skip existing ./data/era_2024_07_vorticity_200.nc
# skip existing ./data/era_2024_08_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_08_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_08_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_08_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_08_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_08_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_08_vorticity_850.nc
# skip existing ./data/era_2024_08_vorticity_600.nc
# skip existing ./data/era_2024_08_vorticity_200.nc
# skip existing ./data/era_2024_09_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_09_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_09_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_09_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_09_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_09_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_09_vorticity_850.nc
# skip existing ./data/era_2024_09_vorticity_600.nc
# skip existing ./data/era_2024_09_vorticity_200.nc
# skip existing ./data/era_2024_10_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_10_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_10_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_10_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_10_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_10_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_10_vorticity_850.nc
# skip existing ./data/era_2024_10_vorticity_600.nc
# skip existing ./data/era_2024_10_vorticity_200.nc
# skip existing ./data/era_2024_11_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_11_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_11_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_11_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_11_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_11_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_11_vorticity_850.nc
# skip existing ./data/era_2024_11_vorticity_600.nc
# skip existing ./data/era_2024_11_vorticity_200.nc
# skip existing ./data/era_2024_12_u_component_of_wind-v_component_of_wind_850.nc
# skip existing ./data/era_2024_12_u_component_of_wind-v_component_of_wind_600.nc
# skip existing ./data/era_2024_12_u_component_of_wind-v_component_of_wind_200.nc
# skip existing ./data/era_2024_12_temperature-relative_humidity_850.nc
# skip existing ./data/era_2024_12_temperature-relative_humidity_600.nc
# skip existing ./data/era_2024_12_temperature-relative_humidity_200.nc
# skip existing ./data/era_2024_12_vorticity_850.nc
# skip existing ./data/era_2024_12_vorticity_600.nc
# skip existing ./data/era_2024_12_vorticity_200.nc

# %%
import os, re, gc, calendar, warnings
import numpy as np
import xarray as xr

import os

DATA_DIR   = r"C:\Users\_s2218026\Documents\lab\data"   # <-- your actual folder
DATA_CLEAN = r"C:\Users\_s2218026\Documents\lab\data_clean"  # new output folder
os.makedirs(DATA_CLEAN, exist_ok=True)


LAT_MAX, LAT_MIN = 30.0, 0.0
LON_MIN, LON_MAX = 100.0, 180.0

def _std_lon360(ds):
    if "longitude" in ds.coords:
        lon = ((ds.longitude + 360) % 360)
        ds  = ds.assign_coords(longitude=lon).sortby("longitude")
    return ds

def _std_lat_desc(ds):
    if "latitude" in ds.coords:
        lat = ds.latitude
        if lat[0] < lat[-1]:
            ds = ds.sortby("latitude", ascending=False)
    return ds

def _clip_bbox(ds):
    if "latitude" in ds.coords and "longitude" in ds.coords:
        return ds.sel(latitude=slice(LAT_MAX+0.5, LAT_MIN-0.5),
                      longitude=slice(LON_MIN-0.5, LON_MAX+0.5))
    return ds

def _normalize_vars(ds):
    rename_map = {
        'u_component_of_wind': 'u',
        'v_component_of_wind': 'v',
        'temperature': 't',
        'relative_humidity': 'r',
        'vorticity': 'vo',
    }
    to_rename = {k:v for k,v in rename_map.items() if k in ds.data_vars}
    return ds.rename(to_rename) if to_rename else ds

def _standardize_dims(ds):
    for cand in ["time","valid_time"]:
        if cand in ds.coords:
            if cand != "time": ds = ds.rename({cand:"time"})
    for cand in ["level","pressure_level","isobaricInhPa"]:
        if cand in ds.coords:
            if cand != "level": ds = ds.rename({cand:"level"})
    return ds

ENGINE = "netcdf4"  # more stable on Windows; switch back to 'h5netcdf' later if you want

def _save_nc(ds, path):
    enc = {v: {'dtype':'float32', 'zlib': False, 'contiguous': True} for v in ds.data_vars}  # fast IO
    ds = ds.map(lambda da: da.astype('float32')).chunk({'time': -1, 'latitude': -1, 'longitude': -1})

    tmp = path + ".tmp"
    # remove stale temp if exists
    try:
        if os.path.exists(tmp):
            os.remove(tmp)
    except Exception:
        pass

    for attempt in range(4):
        try:
            with xr.set_options(file_cache_maxsize=1):
                ds.to_netcdf(tmp, encoding=enc, engine=ENGINE, mode="w")
            # atomic replace so indexers/AV see a complete file
            os.replace(tmp, path)
            return
        except Exception as e:
            # brief backoff; try to clean temp file
            try:
                if os.path.exists(tmp):
                    os.remove(tmp)
            except Exception:
                pass
            if attempt == 3:
                raise
            time.sleep(1.0 + 1.5*attempt)

# %%
def clean_month(y, m):
    keys = [
        "u_component_of_wind-v_component_of_wind_200",
        "u_component_of_wind-v_component_of_wind_600",
        "u_component_of_wind-v_component_of_wind_850",
        "temperature-relative_humidity_200",
        "temperature-relative_humidity_600",
        "temperature-relative_humidity_850",
        "vorticity_850",
    ]
    for key in keys:
        src = os.path.join(DATA_DIR, f"era_{y}_{m:02d}_{key}.nc")
        dst = os.path.join(DATA_CLEAN, f"era_{y}_{m:02d}_{key}.nc")

        if not os.path.exists(src):
            print(f"[{y}-{m:02d}] missing {key}, skip.")
            continue
        if os.path.exists(dst):
            print(f"[{y}-{m:02d}] exists(clean): {key}")
            continue

        ds = xr.open_dataset(src)
        ds = _standardize_dims(_normalize_vars(_clip_bbox(_std_lat_desc(_std_lon360(ds)))))

        assert "time" in ds.coords, "Missing time coord"
        if "level" in ds.coords: assert ds.level.ndim == 1

        for v in ds.data_vars:
            if v in ("u","v"): assert ds[v].max() < 200 and ds[v].min() > -200
            if v == "t":       assert ds[v].max() < 360 and ds[v].min() > 150
            if v == "r":       ds[v] = ds[v].clip(0,100)
            if v == "vo":      assert ds[v].max() < 1e-2 and ds[v].min() > -1e-2

        _save_nc(ds, dst)
        ds.close(); del ds; gc.collect()
        print(f"[{y}-{m:02d}] cleaned -> {dst}")

# %%
pip install h5netcdf
# Out:
# Requirement already satisfied: h5netcdf in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (1.7.3)
# Requirement already satisfied: h5py in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from h5netcdf) (3.12.1)
# Requirement already satisfied: packaging in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from h5netcdf) (24.2)
# Requirement already satisfied: numpy>=1.19.3 in c:\users\_s2218026\appdata\local\anaconda3\lib\site-packages (from h5py->h5netcdf) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
for y in range(1994, 2024):
    for m in range(1, 13):
        try:
            clean_month(y, m)
        except Exception as e:
            warnings.warn(f"[{y}-{m:02d}] cleaning failed: {e}")
# Out:
# [1994-01] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-01] exists(clean): temperature-relative_humidity_200
# [1994-01] exists(clean): temperature-relative_humidity_600
# [1994-01] exists(clean): temperature-relative_humidity_850
# [1994-01] exists(clean): vorticity_850
# [1994-02] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-02] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-02] exists(clean): temperature-relative_humidity_200
# [1994-02] exists(clean): temperature-relative_humidity_600
# [1994-02] exists(clean): temperature-relative_humidity_850
# [1994-02] exists(clean): vorticity_850
# [1994-03] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-03] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-03] exists(clean): temperature-relative_humidity_200
# [1994-03] exists(clean): temperature-relative_humidity_600
# [1994-03] exists(clean): temperature-relative_humidity_850
# [1994-03] exists(clean): vorticity_850
# [1994-04] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-04] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-04] exists(clean): temperature-relative_humidity_200
# [1994-04] exists(clean): temperature-relative_humidity_600
# [1994-04] exists(clean): temperature-relative_humidity_850
# [1994-04] exists(clean): vorticity_850
# [1994-05] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-05] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-05] exists(clean): temperature-relative_humidity_200
# [1994-05] exists(clean): temperature-relative_humidity_600
# [1994-05] exists(clean): temperature-relative_humidity_850
# [1994-05] exists(clean): vorticity_850
# [1994-06] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-06] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-06] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-06] exists(clean): temperature-relative_humidity_200
# [1994-06] exists(clean): temperature-relative_humidity_600
# [1994-06] exists(clean): temperature-relative_humidity_850
# [1994-06] exists(clean): vorticity_850
# [1994-07] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-07] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-07] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-07] exists(clean): temperature-relative_humidity_200
# [1994-07] exists(clean): temperature-relative_humidity_600
# [1994-07] exists(clean): temperature-relative_humidity_850
# [1994-07] exists(clean): vorticity_850
# [1994-08] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-08] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-08] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-08] exists(clean): temperature-relative_humidity_200
# [1994-08] exists(clean): temperature-relative_humidity_600
# [1994-08] exists(clean): temperature-relative_humidity_850
# [1994-08] exists(clean): vorticity_850
# [1994-09] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-09] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-09] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-09] exists(clean): temperature-relative_humidity_200
# [1994-09] exists(clean): temperature-relative_humidity_600
# [1994-09] exists(clean): temperature-relative_humidity_850
# [1994-09] exists(clean): vorticity_850
# [1994-10] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-10] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-10] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-10] exists(clean): temperature-relative_humidity_200
# [1994-10] exists(clean): temperature-relative_humidity_600
# [1994-10] exists(clean): temperature-relative_humidity_850
# [1994-10] exists(clean): vorticity_850
# [1994-11] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-11] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-11] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-11] exists(clean): temperature-relative_humidity_200
# [1994-11] exists(clean): temperature-relative_humidity_600
# [1994-11] exists(clean): temperature-relative_humidity_850
# [1994-11] exists(clean): vorticity_850
# [1994-12] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1994-12] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1994-12] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1994-12] exists(clean): temperature-relative_humidity_200
# [1994-12] exists(clean): temperature-relative_humidity_600
# [1994-12] exists(clean): temperature-relative_humidity_850
# [1994-12] exists(clean): vorticity_850
# [1995-01] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-01] exists(clean): temperature-relative_humidity_200
# [1995-01] exists(clean): temperature-relative_humidity_600
# [1995-01] exists(clean): temperature-relative_humidity_850
# [1995-01] exists(clean): vorticity_850
# [1995-02] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-02] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-02] exists(clean): temperature-relative_humidity_200
# [1995-02] exists(clean): temperature-relative_humidity_600
# [1995-02] exists(clean): temperature-relative_humidity_850
# [1995-02] exists(clean): vorticity_850
# [1995-03] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-03] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-03] exists(clean): temperature-relative_humidity_200
# [1995-03] exists(clean): temperature-relative_humidity_600
# [1995-03] exists(clean): temperature-relative_humidity_850
# [1995-03] exists(clean): vorticity_850
# [1995-04] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-04] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-04] exists(clean): temperature-relative_humidity_200
# [1995-04] exists(clean): temperature-relative_humidity_600
# [1995-04] exists(clean): temperature-relative_humidity_850
# [1995-04] exists(clean): vorticity_850
# [1995-05] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-05] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-05] exists(clean): temperature-relative_humidity_200
# [1995-05] exists(clean): temperature-relative_humidity_600
# [1995-05] exists(clean): temperature-relative_humidity_850
# [1995-05] exists(clean): vorticity_850
# [1995-06] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-06] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-06] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-06] exists(clean): temperature-relative_humidity_200
# [1995-06] exists(clean): temperature-relative_humidity_600
# [1995-06] exists(clean): temperature-relative_humidity_850
# [1995-06] exists(clean): vorticity_850
# [1995-07] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-07] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-07] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-07] exists(clean): temperature-relative_humidity_200
# [1995-07] exists(clean): temperature-relative_humidity_600
# [1995-07] exists(clean): temperature-relative_humidity_850
# [1995-07] exists(clean): vorticity_850
# [1995-08] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-08] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-08] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-08] exists(clean): temperature-relative_humidity_200
# [1995-08] exists(clean): temperature-relative_humidity_600
# [1995-08] exists(clean): temperature-relative_humidity_850
# [1995-08] exists(clean): vorticity_850
# [1995-09] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-09] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-09] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-09] exists(clean): temperature-relative_humidity_200
# [1995-09] exists(clean): temperature-relative_humidity_600
# [1995-09] exists(clean): temperature-relative_humidity_850
# [1995-09] exists(clean): vorticity_850
# [1995-10] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-10] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-10] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-10] exists(clean): temperature-relative_humidity_200
# [1995-10] exists(clean): temperature-relative_humidity_600
# [1995-10] exists(clean): temperature-relative_humidity_850
# [1995-10] exists(clean): vorticity_850
# [1995-11] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-11] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-11] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-11] exists(clean): temperature-relative_humidity_200
# [1995-11] exists(clean): temperature-relative_humidity_600
# [1995-11] exists(clean): temperature-relative_humidity_850
# [1995-11] exists(clean): vorticity_850
# [1995-12] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1995-12] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1995-12] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1995-12] exists(clean): temperature-relative_humidity_200
# [1995-12] exists(clean): temperature-relative_humidity_600
# [1995-12] exists(clean): temperature-relative_humidity_850
# [1995-12] exists(clean): vorticity_850
# [1996-01] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-01] exists(clean): temperature-relative_humidity_200
# [1996-01] exists(clean): temperature-relative_humidity_600
# [1996-01] exists(clean): temperature-relative_humidity_850
# [1996-01] exists(clean): vorticity_850
# [1996-02] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-02] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-02] exists(clean): temperature-relative_humidity_200
# [1996-02] exists(clean): temperature-relative_humidity_600
# [1996-02] exists(clean): temperature-relative_humidity_850
# [1996-02] exists(clean): vorticity_850
# [1996-03] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-03] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-03] exists(clean): temperature-relative_humidity_200
# [1996-03] exists(clean): temperature-relative_humidity_600
# [1996-03] exists(clean): temperature-relative_humidity_850
# [1996-03] exists(clean): vorticity_850
# [1996-04] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-04] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-04] exists(clean): temperature-relative_humidity_200
# [1996-04] exists(clean): temperature-relative_humidity_600
# [1996-04] exists(clean): temperature-relative_humidity_850
# [1996-04] exists(clean): vorticity_850
# [1996-05] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-05] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-05] exists(clean): temperature-relative_humidity_200
# [1996-05] exists(clean): temperature-relative_humidity_600
# [1996-05] exists(clean): temperature-relative_humidity_850
# [1996-05] exists(clean): vorticity_850
# [1996-06] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-06] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-06] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-06] exists(clean): temperature-relative_humidity_200
# [1996-06] exists(clean): temperature-relative_humidity_600
# [1996-06] exists(clean): temperature-relative_humidity_850
# [1996-06] exists(clean): vorticity_850
# [1996-07] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-07] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-07] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-07] exists(clean): temperature-relative_humidity_200
# [1996-07] exists(clean): temperature-relative_humidity_600
# [1996-07] exists(clean): temperature-relative_humidity_850
# [1996-07] exists(clean): vorticity_850
# [1996-08] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-08] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-08] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-08] exists(clean): temperature-relative_humidity_200
# [1996-08] exists(clean): temperature-relative_humidity_600
# [1996-08] exists(clean): temperature-relative_humidity_850
# [1996-08] exists(clean): vorticity_850
# [1996-09] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-09] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-09] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-09] exists(clean): temperature-relative_humidity_200
# [1996-09] exists(clean): temperature-relative_humidity_600
# [1996-09] exists(clean): temperature-relative_humidity_850
# [1996-09] exists(clean): vorticity_850
# [1996-10] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-10] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-10] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-10] exists(clean): temperature-relative_humidity_200
# [1996-10] exists(clean): temperature-relative_humidity_600
# [1996-10] exists(clean): temperature-relative_humidity_850
# [1996-10] exists(clean): vorticity_850
# [1996-11] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-11] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-11] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-11] exists(clean): temperature-relative_humidity_200
# [1996-11] exists(clean): temperature-relative_humidity_600
# [1996-11] exists(clean): temperature-relative_humidity_850
# [1996-11] exists(clean): vorticity_850
# [1996-12] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1996-12] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1996-12] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1996-12] exists(clean): temperature-relative_humidity_200
# [1996-12] exists(clean): temperature-relative_humidity_600
# [1996-12] exists(clean): temperature-relative_humidity_850
# [1996-12] exists(clean): vorticity_850
# [1997-01] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-01] exists(clean): temperature-relative_humidity_200
# [1997-01] exists(clean): temperature-relative_humidity_600
# [1997-01] exists(clean): temperature-relative_humidity_850
# [1997-01] exists(clean): vorticity_850
# [1997-02] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-02] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-02] exists(clean): temperature-relative_humidity_200
# [1997-02] exists(clean): temperature-relative_humidity_600
# [1997-02] exists(clean): temperature-relative_humidity_850
# [1997-02] exists(clean): vorticity_850
# [1997-03] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-03] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-03] exists(clean): temperature-relative_humidity_200
# [1997-03] exists(clean): temperature-relative_humidity_600
# [1997-03] exists(clean): temperature-relative_humidity_850
# [1997-03] exists(clean): vorticity_850
# [1997-04] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-04] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-04] exists(clean): temperature-relative_humidity_200
# [1997-04] exists(clean): temperature-relative_humidity_600
# [1997-04] exists(clean): temperature-relative_humidity_850
# [1997-04] exists(clean): vorticity_850
# [1997-05] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-05] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-05] exists(clean): temperature-relative_humidity_200
# [1997-05] exists(clean): temperature-relative_humidity_600
# [1997-05] exists(clean): temperature-relative_humidity_850
# [1997-05] exists(clean): vorticity_850
# [1997-06] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-06] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-06] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-06] exists(clean): temperature-relative_humidity_200
# [1997-06] exists(clean): temperature-relative_humidity_600
# [1997-06] exists(clean): temperature-relative_humidity_850
# [1997-06] exists(clean): vorticity_850
# [1997-07] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-07] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-07] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-07] exists(clean): temperature-relative_humidity_200
# [1997-07] exists(clean): temperature-relative_humidity_600
# [1997-07] exists(clean): temperature-relative_humidity_850
# [1997-07] exists(clean): vorticity_850
# [1997-08] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-08] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-08] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-08] exists(clean): temperature-relative_humidity_200
# [1997-08] exists(clean): temperature-relative_humidity_600
# [1997-08] exists(clean): temperature-relative_humidity_850
# [1997-08] exists(clean): vorticity_850
# [1997-09] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-09] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-09] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-09] exists(clean): temperature-relative_humidity_200
# [1997-09] exists(clean): temperature-relative_humidity_600
# [1997-09] exists(clean): temperature-relative_humidity_850
# [1997-09] exists(clean): vorticity_850
# [1997-10] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-10] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-10] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-10] exists(clean): temperature-relative_humidity_200
# [1997-10] exists(clean): temperature-relative_humidity_600
# [1997-10] exists(clean): temperature-relative_humidity_850
# [1997-10] exists(clean): vorticity_850
# [1997-11] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-11] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-11] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-11] exists(clean): temperature-relative_humidity_200
# [1997-11] exists(clean): temperature-relative_humidity_600
# [1997-11] exists(clean): temperature-relative_humidity_850
# [1997-11] exists(clean): vorticity_850
# [1997-12] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1997-12] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1997-12] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1997-12] exists(clean): temperature-relative_humidity_200
# [1997-12] exists(clean): temperature-relative_humidity_600
# [1997-12] exists(clean): temperature-relative_humidity_850
# [1997-12] exists(clean): vorticity_850
# [1998-01] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-01] exists(clean): temperature-relative_humidity_200
# [1998-01] exists(clean): temperature-relative_humidity_600
# [1998-01] exists(clean): temperature-relative_humidity_850
# [1998-01] exists(clean): vorticity_850
# [1998-02] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-02] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-02] exists(clean): temperature-relative_humidity_200
# [1998-02] exists(clean): temperature-relative_humidity_600
# [1998-02] exists(clean): temperature-relative_humidity_850
# [1998-02] exists(clean): vorticity_850
# [1998-03] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-03] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-03] exists(clean): temperature-relative_humidity_200
# [1998-03] exists(clean): temperature-relative_humidity_600
# [1998-03] exists(clean): temperature-relative_humidity_850
# [1998-03] exists(clean): vorticity_850
# [1998-04] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-04] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-04] exists(clean): temperature-relative_humidity_200
# [1998-04] exists(clean): temperature-relative_humidity_600
# [1998-04] exists(clean): temperature-relative_humidity_850
# [1998-04] exists(clean): vorticity_850
# [1998-05] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-05] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-05] exists(clean): temperature-relative_humidity_200
# [1998-05] exists(clean): temperature-relative_humidity_600
# [1998-05] exists(clean): temperature-relative_humidity_850
# [1998-05] exists(clean): vorticity_850
# [1998-06] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-06] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-06] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-06] exists(clean): temperature-relative_humidity_200
# [1998-06] exists(clean): temperature-relative_humidity_600
# [1998-06] exists(clean): temperature-relative_humidity_850
# [1998-06] exists(clean): vorticity_850
# [1998-07] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-07] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-07] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-07] exists(clean): temperature-relative_humidity_200
# [1998-07] exists(clean): temperature-relative_humidity_600
# [1998-07] exists(clean): temperature-relative_humidity_850
# [1998-07] exists(clean): vorticity_850
# [1998-08] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-08] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-08] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-08] exists(clean): temperature-relative_humidity_200
# [1998-08] exists(clean): temperature-relative_humidity_600
# [1998-08] exists(clean): temperature-relative_humidity_850
# [1998-08] exists(clean): vorticity_850
# [1998-09] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-09] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-09] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-09] exists(clean): temperature-relative_humidity_200
# [1998-09] exists(clean): temperature-relative_humidity_600
# [1998-09] exists(clean): temperature-relative_humidity_850
# [1998-09] exists(clean): vorticity_850
# [1998-10] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-10] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-10] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-10] exists(clean): temperature-relative_humidity_200
# [1998-10] exists(clean): temperature-relative_humidity_600
# [1998-10] exists(clean): temperature-relative_humidity_850
# [1998-10] exists(clean): vorticity_850
# [1998-11] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-11] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-11] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-11] exists(clean): temperature-relative_humidity_200
# [1998-11] exists(clean): temperature-relative_humidity_600
# [1998-11] exists(clean): temperature-relative_humidity_850
# [1998-11] exists(clean): vorticity_850
# [1998-12] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1998-12] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1998-12] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1998-12] exists(clean): temperature-relative_humidity_200
# [1998-12] exists(clean): temperature-relative_humidity_600
# [1998-12] exists(clean): temperature-relative_humidity_850
# [1998-12] exists(clean): vorticity_850
# [1999-01] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-01] exists(clean): temperature-relative_humidity_200
# [1999-01] exists(clean): temperature-relative_humidity_600
# [1999-01] exists(clean): temperature-relative_humidity_850
# [1999-01] exists(clean): vorticity_850
# [1999-02] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-02] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-02] exists(clean): temperature-relative_humidity_200
# [1999-02] exists(clean): temperature-relative_humidity_600
# [1999-02] exists(clean): temperature-relative_humidity_850
# [1999-02] exists(clean): vorticity_850
# [1999-03] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-03] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-03] exists(clean): temperature-relative_humidity_200
# [1999-03] exists(clean): temperature-relative_humidity_600
# [1999-03] exists(clean): temperature-relative_humidity_850
# [1999-03] exists(clean): vorticity_850
# [1999-04] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-04] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-04] exists(clean): temperature-relative_humidity_200
# [1999-04] exists(clean): temperature-relative_humidity_600
# [1999-04] exists(clean): temperature-relative_humidity_850
# [1999-04] exists(clean): vorticity_850
# [1999-05] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-05] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-05] exists(clean): temperature-relative_humidity_200
# [1999-05] exists(clean): temperature-relative_humidity_600
# [1999-05] exists(clean): temperature-relative_humidity_850
# [1999-05] exists(clean): vorticity_850
# [1999-06] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-06] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-06] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-06] exists(clean): temperature-relative_humidity_200
# [1999-06] exists(clean): temperature-relative_humidity_600
# [1999-06] exists(clean): temperature-relative_humidity_850
# [1999-06] exists(clean): vorticity_850
# [1999-07] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-07] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-07] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-07] exists(clean): temperature-relative_humidity_200
# [1999-07] exists(clean): temperature-relative_humidity_600
# [1999-07] exists(clean): temperature-relative_humidity_850
# [1999-07] exists(clean): vorticity_850
# [1999-08] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-08] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-08] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-08] exists(clean): temperature-relative_humidity_200
# [1999-08] exists(clean): temperature-relative_humidity_600
# [1999-08] exists(clean): temperature-relative_humidity_850
# [1999-08] exists(clean): vorticity_850
# [1999-09] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-09] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-09] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-09] exists(clean): temperature-relative_humidity_200
# [1999-09] exists(clean): temperature-relative_humidity_600
# [1999-09] exists(clean): temperature-relative_humidity_850
# [1999-09] exists(clean): vorticity_850
# [1999-10] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-10] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-10] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-10] exists(clean): temperature-relative_humidity_200
# [1999-10] exists(clean): temperature-relative_humidity_600
# [1999-10] exists(clean): temperature-relative_humidity_850
# [1999-10] exists(clean): vorticity_850
# [1999-11] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-11] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-11] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-11] exists(clean): temperature-relative_humidity_200
# [1999-11] exists(clean): temperature-relative_humidity_600
# [1999-11] exists(clean): temperature-relative_humidity_850
# [1999-11] exists(clean): vorticity_850
# [1999-12] exists(clean): u_component_of_wind-v_component_of_wind_200
# [1999-12] exists(clean): u_component_of_wind-v_component_of_wind_600
# [1999-12] exists(clean): u_component_of_wind-v_component_of_wind_850
# [1999-12] exists(clean): temperature-relative_humidity_200
# [1999-12] exists(clean): temperature-relative_humidity_600
# [1999-12] exists(clean): temperature-relative_humidity_850
# [1999-12] exists(clean): vorticity_850
# [2000-01] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-01] exists(clean): temperature-relative_humidity_200
# [2000-01] exists(clean): temperature-relative_humidity_600
# [2000-01] exists(clean): temperature-relative_humidity_850
# [2000-01] exists(clean): vorticity_850
# [2000-02] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-02] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-02] exists(clean): temperature-relative_humidity_200
# [2000-02] exists(clean): temperature-relative_humidity_600
# [2000-02] exists(clean): temperature-relative_humidity_850
# [2000-02] exists(clean): vorticity_850
# [2000-03] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-03] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-03] exists(clean): temperature-relative_humidity_200
# [2000-03] exists(clean): temperature-relative_humidity_600
# [2000-03] exists(clean): temperature-relative_humidity_850
# [2000-03] exists(clean): vorticity_850
# [2000-04] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-04] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-04] exists(clean): temperature-relative_humidity_200
# [2000-04] exists(clean): temperature-relative_humidity_600
# [2000-04] exists(clean): temperature-relative_humidity_850
# [2000-04] exists(clean): vorticity_850
# [2000-05] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-05] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-05] exists(clean): temperature-relative_humidity_200
# [2000-05] exists(clean): temperature-relative_humidity_600
# [2000-05] exists(clean): temperature-relative_humidity_850
# [2000-05] exists(clean): vorticity_850
# [2000-06] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-06] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-06] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-06] exists(clean): temperature-relative_humidity_200
# [2000-06] exists(clean): temperature-relative_humidity_600
# [2000-06] exists(clean): temperature-relative_humidity_850
# [2000-06] exists(clean): vorticity_850
# [2000-07] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-07] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-07] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-07] exists(clean): temperature-relative_humidity_200
# [2000-07] exists(clean): temperature-relative_humidity_600
# [2000-07] exists(clean): temperature-relative_humidity_850
# [2000-07] exists(clean): vorticity_850
# [2000-08] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-08] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-08] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-08] exists(clean): temperature-relative_humidity_200
# [2000-08] exists(clean): temperature-relative_humidity_600
# [2000-08] exists(clean): temperature-relative_humidity_850
# [2000-08] exists(clean): vorticity_850
# [2000-09] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-09] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-09] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-09] exists(clean): temperature-relative_humidity_200
# [2000-09] exists(clean): temperature-relative_humidity_600
# [2000-09] exists(clean): temperature-relative_humidity_850
# [2000-09] exists(clean): vorticity_850
# [2000-10] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-10] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-10] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-10] exists(clean): temperature-relative_humidity_200
# [2000-10] exists(clean): temperature-relative_humidity_600
# [2000-10] exists(clean): temperature-relative_humidity_850
# [2000-10] exists(clean): vorticity_850
# [2000-11] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-11] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-11] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-11] exists(clean): temperature-relative_humidity_200
# [2000-11] exists(clean): temperature-relative_humidity_600
# [2000-11] exists(clean): temperature-relative_humidity_850
# [2000-11] exists(clean): vorticity_850
# [2000-12] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2000-12] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2000-12] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2000-12] exists(clean): temperature-relative_humidity_200
# [2000-12] exists(clean): temperature-relative_humidity_600
# [2000-12] exists(clean): temperature-relative_humidity_850
# [2000-12] exists(clean): vorticity_850
# [2001-01] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-01] exists(clean): temperature-relative_humidity_200
# [2001-01] exists(clean): temperature-relative_humidity_600
# [2001-01] exists(clean): temperature-relative_humidity_850
# [2001-01] exists(clean): vorticity_850
# [2001-02] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-02] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-02] exists(clean): temperature-relative_humidity_200
# [2001-02] exists(clean): temperature-relative_humidity_600
# [2001-02] exists(clean): temperature-relative_humidity_850
# [2001-02] exists(clean): vorticity_850
# [2001-03] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-03] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-03] exists(clean): temperature-relative_humidity_200
# [2001-03] exists(clean): temperature-relative_humidity_600
# [2001-03] exists(clean): temperature-relative_humidity_850
# [2001-03] exists(clean): vorticity_850
# [2001-04] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-04] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-04] exists(clean): temperature-relative_humidity_200
# [2001-04] exists(clean): temperature-relative_humidity_600
# [2001-04] exists(clean): temperature-relative_humidity_850
# [2001-04] exists(clean): vorticity_850
# [2001-05] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-05] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-05] exists(clean): temperature-relative_humidity_200
# [2001-05] exists(clean): temperature-relative_humidity_600
# [2001-05] exists(clean): temperature-relative_humidity_850
# [2001-05] exists(clean): vorticity_850
# [2001-06] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-06] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-06] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-06] exists(clean): temperature-relative_humidity_200
# [2001-06] exists(clean): temperature-relative_humidity_600
# [2001-06] exists(clean): temperature-relative_humidity_850
# [2001-06] exists(clean): vorticity_850
# [2001-07] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-07] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-07] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-07] exists(clean): temperature-relative_humidity_200
# [2001-07] exists(clean): temperature-relative_humidity_600
# [2001-07] exists(clean): temperature-relative_humidity_850
# [2001-07] exists(clean): vorticity_850
# [2001-08] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-08] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-08] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-08] exists(clean): temperature-relative_humidity_200
# [2001-08] exists(clean): temperature-relative_humidity_600
# [2001-08] exists(clean): temperature-relative_humidity_850
# [2001-08] exists(clean): vorticity_850
# [2001-09] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-09] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-09] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-09] exists(clean): temperature-relative_humidity_200
# [2001-09] exists(clean): temperature-relative_humidity_600
# [2001-09] exists(clean): temperature-relative_humidity_850
# [2001-09] exists(clean): vorticity_850
# [2001-10] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-10] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-10] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-10] exists(clean): temperature-relative_humidity_200
# [2001-10] exists(clean): temperature-relative_humidity_600
# [2001-10] exists(clean): temperature-relative_humidity_850
# [2001-10] exists(clean): vorticity_850
# [2001-11] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-11] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-11] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-11] exists(clean): temperature-relative_humidity_200
# [2001-11] exists(clean): temperature-relative_humidity_600
# [2001-11] exists(clean): temperature-relative_humidity_850
# [2001-11] exists(clean): vorticity_850
# [2001-12] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2001-12] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2001-12] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2001-12] exists(clean): temperature-relative_humidity_200
# [2001-12] exists(clean): temperature-relative_humidity_600
# [2001-12] exists(clean): temperature-relative_humidity_850
# [2001-12] exists(clean): vorticity_850
# [2002-01] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-01] exists(clean): temperature-relative_humidity_200
# [2002-01] exists(clean): temperature-relative_humidity_600
# [2002-01] exists(clean): temperature-relative_humidity_850
# [2002-01] exists(clean): vorticity_850
# [2002-02] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-02] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-02] exists(clean): temperature-relative_humidity_200
# [2002-02] exists(clean): temperature-relative_humidity_600
# [2002-02] exists(clean): temperature-relative_humidity_850
# [2002-02] exists(clean): vorticity_850
# [2002-03] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-03] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-03] exists(clean): temperature-relative_humidity_200
# [2002-03] exists(clean): temperature-relative_humidity_600
# [2002-03] exists(clean): temperature-relative_humidity_850
# [2002-03] exists(clean): vorticity_850
# [2002-04] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-04] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-04] exists(clean): temperature-relative_humidity_200
# [2002-04] exists(clean): temperature-relative_humidity_600
# [2002-04] exists(clean): temperature-relative_humidity_850
# [2002-04] exists(clean): vorticity_850
# [2002-05] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-05] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-05] exists(clean): temperature-relative_humidity_200
# [2002-05] exists(clean): temperature-relative_humidity_600
# [2002-05] exists(clean): temperature-relative_humidity_850
# [2002-05] exists(clean): vorticity_850
# [2002-06] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-06] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-06] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-06] exists(clean): temperature-relative_humidity_200
# [2002-06] exists(clean): temperature-relative_humidity_600
# [2002-06] exists(clean): temperature-relative_humidity_850
# [2002-06] exists(clean): vorticity_850
# [2002-07] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-07] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-07] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-07] exists(clean): temperature-relative_humidity_200
# [2002-07] exists(clean): temperature-relative_humidity_600
# [2002-07] exists(clean): temperature-relative_humidity_850
# [2002-07] exists(clean): vorticity_850
# [2002-08] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-08] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-08] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-08] exists(clean): temperature-relative_humidity_200
# [2002-08] exists(clean): temperature-relative_humidity_600
# [2002-08] exists(clean): temperature-relative_humidity_850
# [2002-08] exists(clean): vorticity_850
# [2002-09] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-09] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-09] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-09] exists(clean): temperature-relative_humidity_200
# [2002-09] exists(clean): temperature-relative_humidity_600
# [2002-09] exists(clean): temperature-relative_humidity_850
# [2002-09] exists(clean): vorticity_850
# [2002-10] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-10] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-10] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-10] exists(clean): temperature-relative_humidity_200
# [2002-10] exists(clean): temperature-relative_humidity_600
# [2002-10] exists(clean): temperature-relative_humidity_850
# [2002-10] exists(clean): vorticity_850
# [2002-11] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-11] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-11] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-11] exists(clean): temperature-relative_humidity_200
# [2002-11] exists(clean): temperature-relative_humidity_600
# [2002-11] exists(clean): temperature-relative_humidity_850
# [2002-11] exists(clean): vorticity_850
# [2002-12] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2002-12] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2002-12] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2002-12] exists(clean): temperature-relative_humidity_200
# [2002-12] exists(clean): temperature-relative_humidity_600
# [2002-12] exists(clean): temperature-relative_humidity_850
# [2002-12] exists(clean): vorticity_850
# [2003-01] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2003-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2003-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2003-01] exists(clean): temperature-relative_humidity_200
# [2003-01] exists(clean): temperature-relative_humidity_600
# [2003-01] exists(clean): temperature-relative_humidity_850
# [2003-01] exists(clean): vorticity_850
# [2003-02] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2003-02] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2003-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2003-02] exists(clean): temperature-relative_humidity_200
# [2003-02] exists(clean): temperature-relative_humidity_600
# [2003-02] exists(clean): temperature-relative_humidity_850
# [2003-02] exists(clean): vorticity_850
# [2003-03] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2003-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2003-03] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2003-03] exists(clean): temperature-relative_humidity_200
# [2003-03] exists(clean): temperature-relative_humidity_600
# [2003-03] exists(clean): temperature-relative_humidity_850
# [2003-03] exists(clean): vorticity_850
# [2003-04] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2003-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2003-04] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2003-04] exists(clean): temperature-relative_humidity_200
# [2003-04] exists(clean): temperature-relative_humidity_600
# [2003-04] exists(clean): temperature-relative_humidity_850
# [2003-04] exists(clean): vorticity_850
# [2003-05] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2003-05] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2003-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2003-05] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2003_05_temperature-relative_humidity_200.nc
# [2003-05] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2003_05_temperature-relative_humidity_600.nc
# [2003-05] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2003_05_temperature-relative_humidity_850.nc
# ...
# [2008-09] exists(clean): temperature-relative_humidity_200
# [2008-09] exists(clean): temperature-relative_humidity_600
# [2008-09] exists(clean): temperature-relative_humidity_850
# [2008-09] exists(clean): vorticity_850
# [2008-10] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2008-10] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2008-10] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2008-10] exists(clean): temperature-relative_humidity_200
# [2008-10] exists(clean): temperature-relative_humidity_600
# [2008-10] exists(clean): temperature-relative_humidity_850
# [2008-10] exists(clean): vorticity_850
# [2008-11] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2008-11] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2008-11] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2008-11] exists(clean): temperature-relative_humidity_200
# [2008-11] exists(clean): temperature-relative_humidity_600
# [2008-11] exists(clean): temperature-relative_humidity_850
# [2008-11] exists(clean): vorticity_850
# [2008-12] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2008-12] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2008-12] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2008-12] exists(clean): temperature-relative_humidity_200
# [2008-12] exists(clean): temperature-relative_humidity_600
# [2008-12] exists(clean): temperature-relative_humidity_850
# [2008-12] exists(clean): vorticity_850
# [2009-01] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2009-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2009-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2009-01] exists(clean): temperature-relative_humidity_200
# [2009-01] exists(clean): temperature-relative_humidity_600
# [2009-01] exists(clean): temperature-relative_humidity_850
# [2009-01] exists(clean): vorticity_850
# [2009-02] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2009-02] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2009-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2009-02] exists(clean): temperature-relative_humidity_200
# [2009-02] exists(clean): temperature-relative_humidity_600
# [2009-02] exists(clean): temperature-relative_humidity_850
# [2009-02] exists(clean): vorticity_850
# [2009-03] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2009-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2009-03] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2009-03] exists(clean): temperature-relative_humidity_200
# [2009-03] exists(clean): temperature-relative_humidity_600
# [2009-03] exists(clean): temperature-relative_humidity_850
# [2009-03] exists(clean): vorticity_850
# [2009-04] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2009-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2009-04] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2009-04] exists(clean): temperature-relative_humidity_200
# [2009-04] exists(clean): temperature-relative_humidity_600
# [2009-04] exists(clean): temperature-relative_humidity_850
# [2009-04] exists(clean): vorticity_850
# [2009-05] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2009-05] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2009-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2009-05] exists(clean): temperature-relative_humidity_200
# [2009-05] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_05_temperature-relative_humidity_600.nc
# [2009-05] exists(clean): temperature-relative_humidity_850
# [2009-05] exists(clean): vorticity_850
# [2009-06] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_06_u_component_of_wind-v_component_of_wind_200.nc
# [2009-06] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2009-06] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_06_u_component_of_wind-v_component_of_wind_850.nc
# [2009-06] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_06_temperature-relative_humidity_200.nc
# [2009-06] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_06_temperature-relative_humidity_600.nc
# [2009-06] exists(clean): temperature-relative_humidity_850
# [2009-06] exists(clean): vorticity_850
# [2009-07] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_07_u_component_of_wind-v_component_of_wind_200.nc
# [2009-07] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2009-07] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_07_u_component_of_wind-v_component_of_wind_850.nc
# [2009-07] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_07_temperature-relative_humidity_200.nc
# [2009-07] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_07_temperature-relative_humidity_600.nc
# [2009-07] exists(clean): temperature-relative_humidity_850
# [2009-07] exists(clean): vorticity_850
# [2009-08] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_08_u_component_of_wind-v_component_of_wind_200.nc
# [2009-08] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_08_u_component_of_wind-v_component_of_wind_600.nc
# [2009-08] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2009-08] exists(clean): temperature-relative_humidity_200
# [2009-08] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_08_temperature-relative_humidity_600.nc
# [2009-08] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_08_temperature-relative_humidity_850.nc
# [2009-08] exists(clean): vorticity_850
# [2009-09] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_09_u_component_of_wind-v_component_of_wind_200.nc
# [2009-09] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_09_u_component_of_wind-v_component_of_wind_600.nc
# [2009-09] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2009-09] exists(clean): temperature-relative_humidity_200
# [2009-09] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_09_temperature-relative_humidity_600.nc
# [2009-09] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_09_temperature-relative_humidity_850.nc
# [2009-09] exists(clean): vorticity_850
# [2009-10] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_10_u_component_of_wind-v_component_of_wind_200.nc
# [2009-10] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_10_u_component_of_wind-v_component_of_wind_600.nc
# [2009-10] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_10_u_component_of_wind-v_component_of_wind_850.nc
# [2009-10] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_10_temperature-relative_humidity_200.nc
# [2009-10] exists(clean): temperature-relative_humidity_600
# [2009-10] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_10_temperature-relative_humidity_850.nc
# [2009-10] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_10_vorticity_850.nc
# [2009-11] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_11_u_component_of_wind-v_component_of_wind_200.nc
# [2009-11] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2009-11] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2009-11] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_11_temperature-relative_humidity_200.nc
# [2009-11] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_11_temperature-relative_humidity_600.nc
# [2009-11] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_11_temperature-relative_humidity_850.nc
# [2009-11] exists(clean): vorticity_850
# [2009-12] exists(clean): u_component_of_wind-v_component_of_wind_200
# [2009-12] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_12_u_component_of_wind-v_component_of_wind_600.nc
# [2009-12] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_12_u_component_of_wind-v_component_of_wind_850.nc
# [2009-12] exists(clean): temperature-relative_humidity_200
# [2009-12] exists(clean): temperature-relative_humidity_600
# [2009-12] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_12_temperature-relative_humidity_850.nc
# [2009-12] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2009_12_vorticity_850.nc
# [2010-01] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_01_u_component_of_wind-v_component_of_wind_200.nc
# [2010-01] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2010-01] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2010-01] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_01_temperature-relative_humidity_200.nc
# [2010-01] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_01_temperature-relative_humidity_600.nc
# [2010-01] exists(clean): temperature-relative_humidity_850
# [2010-01] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_01_vorticity_850.nc
# [2010-02] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_02_u_component_of_wind-v_component_of_wind_200.nc
# [2010-02] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_02_u_component_of_wind-v_component_of_wind_600.nc
# [2010-02] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2010-02] exists(clean): temperature-relative_humidity_200
# [2010-02] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_02_temperature-relative_humidity_600.nc
# [2010-02] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_02_temperature-relative_humidity_850.nc
# [2010-02] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_02_vorticity_850.nc
# [2010-03] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_03_u_component_of_wind-v_component_of_wind_200.nc
# [2010-03] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2010-03] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_03_u_component_of_wind-v_component_of_wind_850.nc
# [2010-03] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_03_temperature-relative_humidity_200.nc
# [2010-03] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_03_temperature-relative_humidity_600.nc
# [2010-03] exists(clean): temperature-relative_humidity_850
# [2010-03] exists(clean): vorticity_850
# [2010-04] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_04_u_component_of_wind-v_component_of_wind_200.nc
# [2010-04] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2010-04] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_04_u_component_of_wind-v_component_of_wind_850.nc
# [2010-04] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_04_temperature-relative_humidity_200.nc
# [2010-04] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_04_temperature-relative_humidity_600.nc
# [2010-04] exists(clean): temperature-relative_humidity_850
# [2010-04] exists(clean): vorticity_850
# [2010-05] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_05_u_component_of_wind-v_component_of_wind_200.nc
# [2010-05] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_05_u_component_of_wind-v_component_of_wind_600.nc
# [2010-05] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2010-05] exists(clean): temperature-relative_humidity_200
# [2010-05] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_05_temperature-relative_humidity_600.nc
# [2010-05] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_05_temperature-relative_humidity_850.nc
# [2010-05] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_05_vorticity_850.nc
# [2010-06] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_06_u_component_of_wind-v_component_of_wind_200.nc
# [2010-06] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_06_u_component_of_wind-v_component_of_wind_600.nc
# [2010-06] exists(clean): u_component_of_wind-v_component_of_wind_850
# [2010-06] exists(clean): temperature-relative_humidity_200
# [2010-06] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_06_temperature-relative_humidity_600.nc
# [2010-06] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_06_temperature-relative_humidity_850.nc
# [2010-06] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_06_vorticity_850.nc
# [2010-07] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_07_u_component_of_wind-v_component_of_wind_200.nc
# [2010-07] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2010-07] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_07_u_component_of_wind-v_component_of_wind_850.nc
# [2010-07] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_07_temperature-relative_humidity_200.nc
# [2010-07] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_07_temperature-relative_humidity_600.nc
# [2010-07] exists(clean): temperature-relative_humidity_850
# [2010-07] exists(clean): vorticity_850
# [2010-08] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_08_u_component_of_wind-v_component_of_wind_200.nc
# [2010-08] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2010-08] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_08_u_component_of_wind-v_component_of_wind_850.nc
# [2010-08] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_08_temperature-relative_humidity_200.nc
# [2010-08] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_08_temperature-relative_humidity_600.nc
# [2010-08] exists(clean): temperature-relative_humidity_850
# [2010-08] exists(clean): vorticity_850
# [2010-09] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_09_u_component_of_wind-v_component_of_wind_200.nc
# [2010-09] exists(clean): u_component_of_wind-v_component_of_wind_600
# [2010-09] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_09_u_component_of_wind-v_component_of_wind_850.nc
# [2010-09] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_09_temperature-relative_humidity_200.nc
# [2010-09] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_09_temperature-relative_humidity_600.nc
# [2010-09] exists(clean): temperature-relative_humidity_850
# [2010-09] exists(clean): vorticity_850
# [2010-10] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_10_u_component_of_wind-v_component_of_wind_200.nc
# [2010-10] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_10_u_component_of_wind-v_component_of_wind_600.nc
# [2010-10] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_10_u_component_of_wind-v_component_of_wind_850.nc
# [2010-10] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_10_temperature-relative_humidity_200.nc
# [2010-10] exists(clean): temperature-relative_humidity_600
# [2010-10] exists(clean): temperature-relative_humidity_850
# [2010-10] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_10_vorticity_850.nc
# [2010-11] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_11_u_component_of_wind-v_component_of_wind_200.nc
# [2010-11] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_11_u_component_of_wind-v_component_of_wind_600.nc
# [2010-11] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_11_u_component_of_wind-v_component_of_wind_850.nc
# [2010-11] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_11_temperature-relative_humidity_200.nc
# [2010-11] exists(clean): temperature-relative_humidity_600
# [2010-11] exists(clean): temperature-relative_humidity_850
# [2010-11] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_11_vorticity_850.nc
# [2010-12] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_12_u_component_of_wind-v_component_of_wind_200.nc
# [2010-12] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_12_u_component_of_wind-v_component_of_wind_600.nc
# [2010-12] cleaned -> C:\Users\_s2218026\Documents\lab\data_clean\era_2010_12_u_component_of_wind-v_component_of_wind_850.nc
